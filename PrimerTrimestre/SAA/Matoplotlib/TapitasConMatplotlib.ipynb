# %% [markdown]
# <a href="https://colab.research.google.com/github/Ims2002/IABD/blob/main/PrimerTrimestre/SAA/Matoplotlib/TapitasConMatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [0, 1]
y = [0, 1]

# Crear el gráfico de línea
plt.plot(x, y)

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

gender_counts = df['Sex'].value_counts()
gender_counts.plot(kind='bar', color=['blue', 'pink'])

plt.xlabel('Género')
plt.ylabel('Número de personas')
plt.title('Distribución de Género de los Pasajeros del Titanic')

plt.show()
